# %% [markdown]
# ### Prueba Markdown

# %% [markdown]
# # Mas Código Markdown

# %% [markdown]
# <h1 style="color:#8C0024">Código html</h1>

# %% [markdown]
# <h2>Mas códdgo html</h1>

# %% [markdown]
# <b>no de nuevo html decía</b>

# %% [markdown]
# print("pueba print")

# %%
a = 25 + 3

# %%
print(a)
# Out:
# 28
